# %%
# !ls
# Out:
# 'Lua — Coding Style_files'	        luarocks-MODULES-documentation.html
# 'Lua — Coding Style.html'	       'Project Structure — Coding Style_files'
#  lua-intro.html			       'Project Structure — Coding Style.html'
#  luapath.info			        Untitled1.ipynb
#  luarocks.list			        Untitled.ipynb
#  luarocks-MODULES-documentation_files   xeus-lua-main

# %%
lines = open("luarocks.list").readlines()
for line in lines:
    line = line.replace("\n","")
    if "luarocks" in line:
        print(line)
# Out:
# argcheck         scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# busted           scm-2 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# cwrap            scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# dkjson           2.6-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# dok              scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# env              scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# gnuplot          scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# graph            scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# hdf5             0-0 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# image            1.1.alpha-0 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# lua-cjson        2.1.0.6-1 (installed) - /home/jack/.luarocks/lib/luarocks/rocks
# lua-term         0.7-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# lua_cliargs      3.0-2 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# luaffi           scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# luafilesystem    1.8.0-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# luasql-sqlite3   2.6.0-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# luassert         1.8.0-0 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# luasystem        0.2.1-0 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# mediator_lua     1.1.2-0 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# moses            1.6.1-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# nn               scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# nngraph          scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# nnx              0.1-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# optim            1.0.5-0 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# paths            scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# penlight         scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# say              1.3-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# sundown          scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# sys              1.1-0 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# threads          scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# torch            scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# totem            0-0 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# trepl            scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# xlua             1.0-0 (installed) - /home/jack/torch/install/lib/luarocks/rocks

# %%
# %load /usr/local/bin/NOTE
#!/usr/bin/python3
import sys
import sqlite3
conn = sqlite3.connect("luarocks.db")
conn.text_factory = str
c = conn.cursor()
if len(sys.argv) < 3:
     print ("\n******* NOTE - Notes Editor **************")
     print ("Not enough options were passed.")     
     print ("NOTE requires 2 arguments. the first -H , -R , -I , -D or -S .\nThe second can be a period.")
     print ("If printing the database -T also add a filename of your choice ( no quotes required ):")
     print (" Example: NOTE -T Data2Text.txt")   
     print ("If wanting to read all entries use -R . (use the period)") 
     print ("even use the period with help.  -H .   must be entered.")
     print ("******************************************\n")
     sys.exit()
mod = sys.argv[1]
def create():

    import sqlite3
    conn = sqlite3.connect("luarocks.db")
    conn.text_factory = str
    c = conn.cursor()
    c.execute("CREATE VIRTUAL TABLE PROJECT using FTS4 (input)")
    conn.commit()
    text = "Database Created"
    return text

def insert(data,conn=conn, c=c):
    c.execute("INSERT into PROJECT values (?)", (data,))
    for row in c.execute("SELECT ROWID,* FROM PROJECT ORDER BY ROWID DESC LIMIT 1"):
        print ("\nPOST VERIFIED:\n",row[0],row[1])
    conn.commit()
    conn.close()
    return data

def search(data,conn=conn, c=c):
    #for row in c.execute("SELECT ROWID,* FROM PROJECT WHERE input MATCH ?",(data,)):
    #    print ("\nINFO Found Here:",row[0],row[1])
    for row in c.execute("SELECT ROWID,* FROM PROJECT"):
        if data in row[1]:    
            print ("\nINFO Found Here:\n",row[0],row[1])
    #conn.commit()
    #conn.close()
def delete(rowid,conn=conn, c=c):
    c.execute("DELETE FROM PROJECT WHERE rowid = ?", (rowid,))
    conn.commit()
    conn.close()
    text = "ROWID "+rowid+" Deleted"
    return text

def main():
    conn = sqlite3.connect("luarocks.db")
    conn.text_factory = str
    c = conn.cursor()
    for row in c.execute("SELECT rowid, * FROM PROJECT"):
        print (row[0],": ",row[1])

def prtmain(filename):
    fn = open(filename, "w")
    conn = sqlite3.connect("luarocks.db")
    conn.text_factory = str
    c = conn.cursor()
    for row in c.execute("SELECT rowid, * FROM PROJECT"):
        TEXT = "id:"+str(row[0])+"\n"+str(row[1])
        TEXT = str(TEXT)
        TEXT = TEXT.replace('\\n','\n')
        TEXT = "".join(TEXT)
        fn.write(TEXT+'\n----\n')

def HELP():
    TXT = """
    USE: NOTE argv[1] argv[2]
    argv[1] sets the mod:
    -I insert / -D delete / -R read / -H help
    examples:
    Notice the entry is in parenthese.
    -I  to insert "STUFF to be inserted"
    NOTE -I "STUFF to be inserted"
    -D to delete where rowid is 3
    NOTE -D 3
    Notice the period after -R . 
    -R . read all
    To search for the term "current project"
    NOTE -S 3
    -S "current project"
    NOTE -R .
    -H help on options
    NOTE -H .
    """
    print (TXT)

if mod == "-H" or mod == "h":
    HELP()        
if mod == "-R" or mod == "-r":
    main()
if mod == "-I" or mod == "-i":
    data = sys.argv[2]
    insert(data)
if mod == "-D" or mod == "-d":
    rowid = sys.argv[2]
    delete(rowid) 
if mod == "-S" or mod == "-s":
    data = sys.argv[2]
    search(data)       
if mod == "-T":
    filename = sys.argv[2]
    prtmain(filename)
if mod == "-C" or mod == "-c":
    create()
    print (create)
else:
    print ("_________________\n")
    print (sys.argv[2],"Command Completed")

# %%
def create():

    import sqlite3
    conn = sqlite3.connect("luarocks.db")
    conn.text_factory = str
    c = conn.cursor()
    c.execute("CREATE VIRTUAL TABLE PROJECT using FTS4 (input)")
    conn.commit()
    text = "Database Created"
    return text
create()
# Out:
# 'Database Created'

# %%
import sqlite3
def insert(data):
    conn = sqlite3.connect("luarocks.db")
    conn.text_factory = str
    c = conn.cursor()
    c.execute("INSERT into PROJECT values (?)", (data,))
    for row in c.execute("SELECT ROWID,* FROM PROJECT ORDER BY ROWID DESC LIMIT 1"):
        print ("\nPOST VERIFIED:\n",row[0],row[1])
    conn.commit()
    conn.close()
    return data

# %%
import sqlite3
lines = open("luarocks.list").readlines()
for line in lines:
    data = line.replace("\n","")
    if "luarocks" in data:
        insert(data)
        print(data)
# Out:
# POST VERIFIED:
#  1 argcheck         scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# argcheck         scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
#
# POST VERIFIED:
#  2 busted           scm-2 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# busted           scm-2 (installed) - /home/jack/torch/install/lib/luarocks/rocks
#
# POST VERIFIED:
#  3 cwrap            scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# cwrap            scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
#
# POST VERIFIED:
#  4 dkjson           2.6-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# dkjson           2.6-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
#
# POST VERIFIED:
#  5 dok              scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# dok              scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
#
# POST VERIFIED:
#  6 env              scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# env              scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
#
# POST VERIFIED:
#  7 gnuplot          scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# gnuplot          scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
#
# POST VERIFIED:
#  8 graph            scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# graph            scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
#
# POST VERIFIED:
#  9 hdf5             0-0 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# hdf5             0-0 (installed) - /home/jack/torch/install/lib/luarocks/rocks
#
# POST VERIFIED:
#  10 image            1.1.alpha-0 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# image            1.1.alpha-0 (installed) - /home/jack/torch/install/lib/luarocks/rocks
#
# POST VERIFIED:
#  11 lua-cjson        2.1.0.6-1 (installed) - /home/jack/.luarocks/lib/luarocks/rocks
# lua-cjson        2.1.0.6-1 (installed) - /home/jack/.luarocks/lib/luarocks/rocks
#
# POST VERIFIED:
#  12 lua-term         0.7-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# lua-term         0.7-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
#
# POST VERIFIED:
#  13 lua_cliargs      3.0-2 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# lua_cliargs      3.0-2 (installed) - /home/jack/torch/install/lib/luarocks/rocks
#
# POST VERIFIED:
#  14 luaffi           scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# luaffi           scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
#
# POST VERIFIED:
#  15 luafilesystem    1.8.0-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# luafilesystem    1.8.0-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
#
# POST VERIFIED:
#  16 luasql-sqlite3   2.6.0-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# luasql-sqlite3   2.6.0-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
#
# POST VERIFIED:
#  17 luassert         1.8.0-0 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# luassert         1.8.0-0 (installed) - /home/jack/torch/install/lib/luarocks/rocks
#
# POST VERIFIED:
#  18 luasystem        0.2.1-0 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# luasystem        0.2.1-0 (installed) - /home/jack/torch/install/lib/luarocks/rocks
#
# POST VERIFIED:
#  19 mediator_lua     1.1.2-0 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# mediator_lua     1.1.2-0 (installed) - /home/jack/torch/install/lib/luarocks/rocks
#
# POST VERIFIED:
#  20 moses            1.6.1-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# moses            1.6.1-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
#
# POST VERIFIED:
#  21 nn               scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# nn               scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
#
# POST VERIFIED:
#  22 nngraph          scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# nngraph          scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
#
# POST VERIFIED:
#  23 nnx              0.1-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# nnx              0.1-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
#
# POST VERIFIED:
#  24 optim            1.0.5-0 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# optim            1.0.5-0 (installed) - /home/jack/torch/install/lib/luarocks/rocks
#
# POST VERIFIED:
#  25 paths            scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# paths            scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
#
# POST VERIFIED:
#  26 penlight         scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# penlight         scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
#
# POST VERIFIED:
#  27 say              1.3-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# say              1.3-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
#
# POST VERIFIED:
#  28 sundown          scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# sundown          scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
#
# POST VERIFIED:
#  29 sys              1.1-0 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# sys              1.1-0 (installed) - /home/jack/torch/install/lib/luarocks/rocks
#
# POST VERIFIED:
#  30 threads          scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# threads          scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
#
# POST VERIFIED:
#  31 torch            scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# torch            scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
#
# POST VERIFIED:
#  32 totem            0-0 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# totem            0-0 (installed) - /home/jack/torch/install/lib/luarocks/rocks
#
# POST VERIFIED:
#  33 trepl            scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# trepl            scm-1 (installed) - /home/jack/torch/install/lib/luarocks/rocks
#
# POST VERIFIED:
#  34 xlua             1.0-0 (installed) - /home/jack/torch/install/lib/luarocks/rocks
# xlua             1.0-0 (installed) - /home/jack/torch/install/lib/luarocks/rocks
